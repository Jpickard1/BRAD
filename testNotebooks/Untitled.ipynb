# %%
# /home/machoi/RAG2/RAG-DEV/BRAD/__init__.py

import agent as ag # If `brad` is a submodule or a function

#sk--HCgSGjJfCiQSMyN7fz9u-zjaGycjhzdCPz0sUyZ9eT3BlbkFJBXswhG2U5YpXJcYiCfhBZHKJrjxkcACljcnzxlR3gA

# %%
bot = ag.Agent()
bot.invoke('/force SCRAPE PUBMED Cellular Reprogramming')
# Out:
# /home/machoi/RAG2/RAG-DEV/testNotebooks/logs
# Enter your Open AI API key:  ········
# Would you like to use a database with BRAD [Y/N]?
#  N
# 2024-11-18 11:02:38 INFO semantic_router.utils.logger local
# Welcome to RAG! The chat log from this conversation will be saved to /home/machoi/RAG2/RAG-DEV/testNotebooks/logs/November 18, 2024 at 11:02:21 AM/log.json. How can I help?
# ==================================================
# BRAD >> 1:
# /home/machoi/.local/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use RunnableWithMessageHistory: https://api.python.langchain.com/en/latest/runnables/langchain_core.runnables.history.RunnableWithMessageHistory.html instead.
#   warn_deprecated(
# 2024-11-18 11:02:40,497 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# searching the following on pubmed: cellular reprogramming
#                                                 Title  \
# 0   Maturation of the adrenal medulla--IV. Effects...
# 1   Comparison between procaine and isocarboxazid ...
# 2   Metal substitutions incarbonic anhydrase: a ha...
# 3   Delineation of the intimate details of the bac...
# 4   Formate assay in body fluids: application in m...
# 5   Effect of chloroquine on cultured fibroblasts:...
# 6   Radiochemical assay of glutathione S-epoxide t...
# 7   Delineation of the intimate details of the bac...
# 8   Maturation of the adrenal medulla--IV. Effects...
# 9   Formate assay in body fluids: application in m...
# 10  Metal substitutions incarbonic anhydrase: a ha...
# 11  Studies of oxygen binding energy to hemoglobin...
# 12  Delineation of the intimate details of the bac...
# 13  Effect of chloroquine on cultured fibroblasts:...
# 14  Radiochemical assay of glutathione S-epoxide t...
# 15  Formate assay in body fluids: application in m...
# 16  Delineation of the intimate details of the bac...
# 17  Metal substitutions incarbonic anhydrase: a ha...
# 18  Atomic models for the polypeptide backbones of...
# 19  Studies of oxygen binding energy to hemoglobin...
# 20  Formate assay in body fluids: application in m...
# 21  Radiochemical assay of glutathione S-epoxide t...
# 22  Maturation of the adrenal medulla--IV. Effects...
# 23  Metal substitutions incarbonic anhydrase: a ha...
# 24  Metal substitutions incarbonic anhydrase: a ha...
# 25  Effect of chloroquine on cultured fibroblasts:...
# 26  Formate assay in body fluids: application in m...
# 27  Comparison between procaine and isocarboxazid ...
# 28  Delineation of the intimate details of the bac...
# 29  Radiochemical assay of glutathione S-epoxide t...
# 30  Metal substitutions incarbonic anhydrase: a ha...
# 31  Delineation of the intimate details of the bac...
# 32  Atomic models for the polypeptide backbones of...
# 33  Studies of oxygen binding energy to hemoglobin...
# 34  Formate assay in body fluids: application in m...
# 35  Effect of chloroquine on cultured fibroblasts:...
# 36  Studies of oxygen binding energy to hemoglobin...
# 37  Comparison between procaine and isocarboxazid ...
# 38  Metal substitutions incarbonic anhydrase: a ha...
# 39  Maturation of the adrenal medulla--IV. Effects...
# 40  Comparison between procaine and isocarboxazid ...
# 41  Effect of chloroquine on cultured fibroblasts:...
# 42  Studies of oxygen binding energy to hemoglobin...
# 43  Metal substitutions incarbonic anhydrase: a ha...
# 44  Metal substitutions incarbonic anhydrase: a ha...
# 45  Maturation of the adrenal medulla--IV. Effects...
# 46  Studies of oxygen binding energy to hemoglobin...
# 47  Atomic models for the polypeptide backbones of...
# 48  Delineation of the intimate details of the bac...
# 49  Radiochemical assay of glutathione S-epoxide t...
# 50  Comparison between procaine and isocarboxazid ...
# 51  Formate assay in body fluids: application in m...
#
#                                           Authors     Abstract
# 0                       T R Anderson; T A Slotkin  No Abstract
# 1                                 K Moroi; T Sato  No Abstract
# 2                           R J Smith; R G Bryant  No Abstract
# 3                             K S Bose; R H Sarma  No Abstract
# 4   A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 5      U N Wiesmann; S DiDonato; N N Herschkowitz  No Abstract
# 6                          J Marniemi; M G Parkki  No Abstract
# 7                             K S Bose; R H Sarma  No Abstract
# 8                       T R Anderson; T A Slotkin  No Abstract
# 9   A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 10                          R J Smith; R G Bryant  No Abstract
# 11              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 12                            K S Bose; R H Sarma  No Abstract
# 13     U N Wiesmann; S DiDonato; N N Herschkowitz  No Abstract
# 14                         J Marniemi; M G Parkki  No Abstract
# 15  A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 16                            K S Bose; R H Sarma  No Abstract
# 17                          R J Smith; R G Bryant  No Abstract
# 18                      W A Hendrickson; K B Ward  No Abstract
# 19              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 20  A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 21                         J Marniemi; M G Parkki  No Abstract
# 22                      T R Anderson; T A Slotkin  No Abstract
# 23                          R J Smith; R G Bryant  No Abstract
# 24                          R J Smith; R G Bryant  No Abstract
# 25     U N Wiesmann; S DiDonato; N N Herschkowitz  No Abstract
# 26  A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 27                                K Moroi; T Sato  No Abstract
# 28                            K S Bose; R H Sarma  No Abstract
# 29                         J Marniemi; M G Parkki  No Abstract
# 30                          R J Smith; R G Bryant  No Abstract
# 31                            K S Bose; R H Sarma  No Abstract
# 32                      W A Hendrickson; K B Ward  No Abstract
# 33              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 34  A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# 35     U N Wiesmann; S DiDonato; N N Herschkowitz  No Abstract
# 36              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 37                                K Moroi; T Sato  No Abstract
# 38                          R J Smith; R G Bryant  No Abstract
# 39                      T R Anderson; T A Slotkin  No Abstract
# 40                                K Moroi; T Sato  No Abstract
# 41     U N Wiesmann; S DiDonato; N N Herschkowitz  No Abstract
# 42              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 43                          R J Smith; R G Bryant  No Abstract
# 44                          R J Smith; R G Bryant  No Abstract
# 45                      T R Anderson; T A Slotkin  No Abstract
# 46              Y W Chow; R Pietranico; A Mukerji  No Abstract
# 47                      W A Hendrickson; K B Ward  No Abstract
# 48                            K S Bose; R H Sarma  No Abstract
# 49                         J Marniemi; M G Parkki  No Abstract
# 50                                K Moroi; T Sato  No Abstract
# 51  A B Makar; K E McMartin; M Palese; T R Tephly  No Abstract
# Would you like to download these articles [Y/N]?
